# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(
    "../data/SpamData",sep="\t",names=["label", "message"]
)

# %%
df.shape
# Out:
# (5572, 2)

# %%
df.sample(5)
# Out:
#      label                                            message
# 1389   ham     Oh k.i think most of wi and nz players unsold.
# 3213   ham                  We got a divorce. Lol. She.s here
# 5107   ham  I REALLY NEED 2 KISS U I MISS U MY BABY FROM U...
# 3210   ham  Havent mus ask if u can 1st wat. Of meet 4 lun...
# 5490   ham                            K. I will sent it again

# %%
df['label'] = df['label'].replace({'spam': 1, 'ham': 0})
# Out:
# C:\Users\himan\AppData\Local\Temp\ipykernel_4940\1597990892.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['label'] = df['label'].replace({'spam': 1, 'ham': 0})

# %%
df.isnull().sum()
# Out:
# label      0
# message    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(403)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv("../data/SpamData.csv", index=False)
